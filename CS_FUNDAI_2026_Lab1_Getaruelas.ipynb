# %% [markdown]
# <a href="https://colab.research.google.com/github/jessgab-prog/FUNDAI-Laboratories-Getaruelas/blob/main/CS_FUNDAI_2026_Lab1_Getaruelas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1: Environment Onboarding
#
# ## Fundamentals of Artificial Intelligence
#
# **Name:** Getaruelas, Jess Gabriel A.
# **Course:** BSIT
# **Section:** 09282-FUNDAI
# **Date:** 8-19-2026
#
# **GitHub URL:** https://github.com/jessgab-prog/FUNDAI-Laboratories-Getaruelas.git
#
# ## Description
# This laboratory introduces the use of Google Colab and GitHub for AI laboratory activities. It also implements a simple intelligent agent.

# %%
import sys
import datetime

print("Python version:")
print(sys.version, "\n")

print("Current Date:")
print(datetime.date.today())
# Out:
# Python version:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#
# Current Date:
# 2026-08-18

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from genericpath import exists
import os

folder_path = "/content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI_Lab1"
os.makedirs(folder_path, exist_ok=True)

print("Folder ready:", folder_path)
# Out:
# Folder ready: /content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI_Lab1

# %% [markdown]
# ## Simple Intelligent Agent
#
# This simple agent receives a room condition as a percept and produces an action.
#
# The agent follows a condition-action rule:
#
# - If the room is dirty, the agent cleans.
# - If the room is clean, the agent rests.
# - If the room condition is unknown, the agent inspects.

# %%
def simple_reflex_agent(room_condition):
  """
  A simple reflex agent that decides an action based on the room condition.
  """
  room_condition = room_condition.strip().lower()
  if room_condition == "dirty":
    return "CLEAN"
  elif room_condition == "clean":
    return "REST"
  else:
    return "INSPECT"

# %%
percepts = ["dirty", "clean", "dirty", "unknown"]

print("Simple Reflex Agent Test")
print("-" * 30)

for i, percept in enumerate(percepts, start=1):
  action = simple_reflex_agent(percept)
  print(f"Percept {i}: {percept:<8} -> Action: {action}")
# Out:
# Simple Reflex Agent Test
# ------------------------------
# Percept 1: dirty    -> Action: CLEAN
# Percept 2: clean    -> Action: REST
# Percept 3: dirty    -> Action: CLEAN
# Percept 4: unknown  -> Action: INSPECT

# %% [markdown]
# ## Performance Measure
#
# A simple performance measure gives a score when the agent chooses the correct action for the given percept.

# %%
score = 0
total = len(percepts)

for percept in percepts:
  action = simple_reflex_agent(percept)

  if percept == "dirty" and action == "CLEAN":
    score += 1
  elif percept == "clean" and action == "REST":
    score += 1
  elif percept == "unknown" and action == "INSPECT":
    score += 1

print(f"Agent score: {score}/{total}")
# Out:
# Agent score: 4/4

# %% [markdown]
# ## Guide Questions and Answers
# ### 1. What is an intelligent agent?
# **Answer:** An intelligent agent is a system that can observe or sense its environment and then make an action based on what it detects.
# ### 2. What are the sensors and actuators in this simple agent example?
# **Answer:** The sensor is the room condition that the agent detects. The actuator is the action it performs, such as CLEAN, REST, or INSPECT, depending on the room condition.
# ### 3. Why is documentation important in AI laboratory work?
# **Answer:** Documentation is important because it helps explain what the code does, shows the results of the activity, and helps the instructor understand and evaluate our work.

# %% [markdown]
# ## Reflection
# ### Challenges Encountered
# - One of the challenges I encountered was understanding how the intelligent agent works and how the sensor input affects the action it performs. I also had to understand the purpose of each part of the code and make sure that the results were correct.
#
# ### What I Learned
# - I learned how an intelligent agent uses sensors to observe its environment and actuators to perform actions.
# - I also learned that proper documentation is important because it helps explain the process, code, and results of the activity.
# - I gained a better understanding of how a simple AI agent makes decisions based on the information it receives.
